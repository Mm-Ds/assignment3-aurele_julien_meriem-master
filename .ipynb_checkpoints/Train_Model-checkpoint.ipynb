# %% [markdown]
# # Robust Neural Network

# %% [markdown]
# ## Exploring the CIFAR-10 Dataset

# %%
from model import Model
from attacks import *
from matplotlib import pyplot as plt
from scipy.spatial.distance import euclidean
import torch
import matplotlib.pyplot as plt
from torchvision.transforms import Normalize
import numpy as np

# %%
model = Model()
# Out:
# cpu

# %%
model.loadData(bs=1)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/cifar-10-python.tar.gz to ./data

# %%
classes = model.dataset.classes
classes
# Out:
# ['airplane',
#  'automobile',
#  'bird',
#  'cat',
#  'deer',
#  'dog',
#  'frog',
#  'horse',
#  'ship',
#  'truck']

# %%
class_count = {}
for _, index in model.dataset:
    label = classes[index]
    if label not in class_count:
        class_count[label] = 0
    class_count[label] += 1
class_count
# Out:
# {'airplane': 5000,
#  'automobile': 5000,
#  'bird': 5000,
#  'cat': 5000,
#  'deer': 5000,
#  'dog': 5000,
#  'frog': 5000,
#  'horse': 5000,
#  'ship': 5000,
#  'truck': 5000}

# %%
import matplotlib.pyplot as plt
import numpy as np
import torchvision

def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
dataiter = iter(model.trainloader)
images, labels = dataiter.next()

# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join('%5s' % model.classes[labels[j]] for j in range(1)))
# Out:
#  bird

# %%
len(model.trainset)
# Out:
# 50000

# %%
len(model.testset)
# Out:
# 10000

# %%
x,y = model.trainset[0]

# %%
print('taille d\'une image : {}'.format(x.shape))
# Out:
# taille d'une image : torch.Size([3, 32, 32])

# %%
model.model
# Out:
# Net(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (fc1): Linear(in_features=512, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=10, bias=True)
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (apool): AvgPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0)
# )

# %%
model.loadModel()
#model.trainModel(epochs=10)

# %%
train_loss = model.history_train
test_loss = model.history_test
epochs = [i for i in range(len(train_loss))]

fig = plt.figure()
plt.plot(epochs, train_loss, label='train')
plt.plot(epochs, test_loss, label='test')
plt.legend()
plt.show()

# %%
model.testModel()
# Out:
# Accuracy of the network on the 10000 test images: 76 %

# %%
import torch

class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
with torch.no_grad():
    for data in model.testloader:
        inputs, labels = data[0].to(model.device), data[1].to(model.device)
        outputs = model.model(inputs)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels)
        for i in range(1):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1


for i in range(10):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy of airplane : 79 %
# Accuracy of automobile : 89 %
# Accuracy of  bird : 66 %
# Accuracy of   cat : 49 %
# Accuracy of  deer : 70 %
# Accuracy of   dog : 69 %
# Accuracy of  frog : 85 %
# Accuracy of horse : 79 %
# Accuracy of  ship : 84 %
# Accuracy of truck : 86 %

# %%
model.saveModel()

# %%
import numpy as np
index = 1

img = model.testset[index][0] / 2 + 0.5     # unnormalize
label = model.testset[index][1]
npimg = img.numpy()
print('True Label :' + classes[label])
plt.imshow(np.transpose(npimg, (1, 2, 0)))
#plt.show()
# Out:
# True Label :ship

# %% [markdown]
# ## Hidden layers' exploration

# %%
img
pred = model.identify(img)    #can work with the reloaded model, identify calling forward indeed.
classes[pred]
print(len(model.model.layers))
# Out:
# 7

# %%
def denormalize(img):
  return img / 2 + 0.5

# %%
fgsm = FGSM_Attack(model)
# fgsm_params={'eps': 0.8,
#             'step':0.01,
#             'norm':2,
#             'n_iterations':25}

fgsm_params={'eps':0.05}

# %%
pairs_dict={}
normalize = lambda x: (x-torch.mean(x))/torch.std(x)

for i in range(len(model.testset)):
  dist_mat=[]
  dist_mats=[]
  x = model.testset[i][0]
  x = denormalize(x)
  y = model.testset[i][1]
  
  pred=classes[model.identify(x)]
  latent_reps=model.model.layers
  latent_reps= [torch.flatten(t) for t in latent_reps]    #flatten the layers' outputs
  latent_reps= [ normalize(t) for t in latent_reps]       #normalize them 

  #generate adversarial

  x = (x[None, ...]).to(model.device)
  y = torch.tensor([y]).to(model.device)

  adv_x =fgsm.generate_adv(x,y, targeted=True,
                               **fgsm_params)
  adv_x= torch.squeeze(denormalize(adv_x), 0)
  pred_adv=classes[model.identify(adv_x)] 
  latent_reps_adv=model.model.layers
  adv_latent_reps= [torch.flatten(t) for t in adv_latent_reps]
  adv_latent_reps= [normalize(t) for t in adv_latent_reps] 
  
  for j in range(len(latent_reps)):
    dist_mat.append(euclidean(latent_reps[j],adv_latent_reps[j]))    #compute euclidean distance over each pair (hidden_layer_i(original), hidden_layer_i(adversarial)) 

  key=str(i)+'-'+pred+'-'+ pred_adv
  pairs_dict[key]=(latent_reps, adv_latent_reps, dist_mat)
  
  # dits_mats.append

# %%
print(pairs_dict.keys())
print(len(pairs_dict))
# Out:
# dict_keys(['0-cat-cat', '1-ship-cat', '2-ship-cat', '3-airplane-airplane', '4-cat-cat', '5-cat-cat', '6-automobile-cat', '7-cat-cat', '8-cat-cat', '9-airplane-cat', '10-airplane-cat', '11-truck-cat', '12-dog-cat', '13-horse-cat', '14-truck-cat', '15-ship-cat', '16-horse-cat', '17-cat-cat', '18-ship-cat', '19-cat-cat', '20-airplane-cat', '21-airplane-airplane', '22-bird-deer', '23-truck-cat', '24-deer-cat', '25-cat-cat', '26-cat-cat', '27-airplane-cat', '28-deer-cat', '29-deer-cat', '30-deer-cat', '31-cat-cat', '32-cat-cat', '33-cat-cat', '34-ship-cat', '35-ship-cat', '36-cat-cat', '37-airplane-deer', '38-ship-cat', '39-cat-cat', '40-airplane-cat', '41-frog-cat', '42-cat-cat', '43-frog-cat', '44-airplane-airplane', '45-truck-cat', '46-cat-cat', '47-ship-cat', '48-deer-cat', '49-bird-cat', '50-ship-cat', '51-ship-cat', '52-cat-cat', '53-cat-cat', '54-ship-ship', '55-ship-cat', '56-cat-cat', '57-ship-cat', '58-deer-cat', '59-cat-cat', '60-deer-cat', '61-cat-cat', '62-airplane-cat', '63-airplane-cat', '64-cat-cat', '65-bird-cat', '66-ship-cat', '67-bird-cat', '68-cat-cat', '69-ship-cat', '70-cat-cat', '71-cat-cat', '72-ship-ship', '73-ship-cat', '74-ship-cat', '75-bird-cat', '76-airplane-cat', '77-cat-cat', '78-cat-cat', '79-ship-cat', '80-ship-cat', '81-ship-cat', '82-automobile-cat', '83-deer-cat', '84-bird-cat', '85-ship-cat', '86-bird-cat', '87-ship-cat', '88-ship-cat', '89-airplane-cat', '90-airplane-airplane', '91-cat-cat', '92-ship-ship', '93-frog-cat', '94-deer-cat', '95-frog-cat', '96-airplane-cat', '97-cat-cat', '98-airplane-airplane', '99-cat-cat', '100-deer-cat', '101-cat-cat', '102-cat-cat', '103-cat-cat', '104-ship-cat', '105-ship-cat', '106-airplane-cat', '107-deer-cat', '108-ship-ship', '109-horse-cat', '110-deer-cat', '111-airplane-airplane', '112-bird-cat', '113-ship-cat', '114-ship-cat', '115-cat-cat', '116-airplane-cat', '117-deer-cat', '118-bird-cat', '119-cat-cat', '120-ship-cat', '121-cat-cat', '122-cat-cat', '123-bird-cat', '124-airplane-cat', '125-bird-cat', '126-ship-cat', '127-cat-cat', '128-deer-cat', '129-airplane-cat', '130-bird-cat', '131-truck-cat', '132-ship-cat', '133-truck-cat', '134-cat-cat', '135-cat-cat', '136-ship-cat', '137-cat-cat', '138-bird-cat', '139-ship-cat', '140-cat-cat', '141-dog-cat', '142-cat-cat', '143-cat-cat', '144-ship-ship', '145-ship-cat', '146-cat-cat', '147-dog-cat', '148-bird-cat', '149-bird-cat', '150-ship-ship', '151-ship-cat', '152-airplane-cat', '153-airplane-airplane', '154-bird-cat', '155-cat-cat', '156-cat-cat', '157-ship-cat', '158-cat-cat', '159-ship-deer', '160-bird-cat', '161-airplane-cat', '162-deer-cat', '163-cat-cat', '164-airplane-cat', '165-deer-cat', '166-cat-cat', '167-cat-cat', '168-cat-cat', '169-ship-cat', '170-airplane-cat', '171-airplane-cat', '172-cat-cat', '173-ship-cat', '174-airplane-cat', '175-truck-cat', '176-cat-cat', '177-cat-cat', '178-cat-cat', '179-airplane-airplane', '180-airplane-cat', '181-dog-cat', '182-bird-bird', '183-cat-cat', '184-cat-cat', '185-ship-cat', '186-ship-cat', '187-cat-cat', '188-cat-cat', '189-ship-airplane', '190-cat-cat', '191-cat-cat', '192-ship-airplane', '193-automobile-cat', '194-cat-cat', '195-bird-cat', '196-ship-ship', '197-cat-cat', '198-cat-cat', '199-cat-cat', '200-cat-cat', '201-ship-cat', '202-airplane-cat', '203-airplane-deer', '204-cat-cat', '205-cat-cat', '206-ship-cat', '207-ship-cat', '208-horse-cat', '209-ship-cat', '210-ship-cat', '211-ship-cat', '212-cat-cat', '213-ship-cat', '214-ship-cat', '215-deer-cat', '216-horse-deer', '217-truck-cat', '218-cat-cat', '219-deer-cat', '220-deer-cat', '221-cat-cat', '222-ship-cat', '223-cat-cat', '224-cat-cat', '225-truck-cat', '226-ship-cat', '227-cat-cat', '228-cat-cat', '229-deer-cat', '230-dog-cat', '231-automobile-cat', '232-bird-cat', '233-airplane-cat', '234-ship-cat', '235-airplane-airplane', '236-ship-cat', '237-ship-cat', '238-cat-cat', '239-cat-cat', '240-airplane-cat', '241-airplane-cat', '242-ship-cat', '243-ship-cat', '244-bird-airplane', '245-sh ...
# 10000

# %%
#plot pairs of the mean distances for each hidden layer

tensor_dists= torch.FloatTensor([pairs_dict[key][2] for key in pairs_dict.keys()])
mean_dists= torch.mean(tensor_dists, 0)
#plot the mean distances 
plt.scatter(range(len(mean_dists)),mean_dists, c='red')

plt.ylabel("mean distance")
plt.xlabel("hidden layer")
plt.title("mean distance between adversarial and original examples' latent representations for each hidden layer")
plt.show()

#plot some individual distance pairs (just to check if the distances are not much different from the mean (should see std deviation instead))
for i in range(10):
  plt.scatter(range(len(tensor_dists[i])),tensor_dists[i])
  plt.ylabel("mean distance")
  plt.xlabel("hidden layer")
  plt.title("mean distance between adversarial and original examples' latent representations for each hidden layer")
  plt.show()
